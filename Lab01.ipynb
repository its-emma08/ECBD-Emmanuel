# %%
import pandas as pd

# %%
#Conjunto de datos 
usuarios = {
	"usuario" : ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"],
	"edad" : [22, 35, 28, 40, 19, 26, 45, 29],
	"ciudad" : ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Mérida", "Tijuana", "Toluca"],
	"compras_realizadas" : [5,12,3,29,1,7,4,15],
	"activo" : [True, False, True, True, False, True, False, True],
	"fecha-registro" : [ "2026-01-10", "2026-01-12", "2026-02-10", "2025-01-05", "2026-05-05",  "2026-02-21", "2026-03-09", "2026-04-08"]
}

# %%
#Convertir a DataFrame 
df = pd.DataFrame(usuarios)

# %%
print(df)
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha-registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      Luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2026-02-10
# 3  Carolina    40       Puebla                  29    True     2025-01-05
# 4     Sofia    19       Cancún                   1   False     2026-05-05
# 5     Pedro    26       Mérida                   7    True     2026-02-21
# 6     Elena    45      Tijuana                   4   False     2026-03-09
# 7     Diego    29       Toluca                  15    True     2026-04-08

# %%
df.head()
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha-registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      Luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2026-02-10
# 3  Carolina    40       Puebla                  29    True     2025-01-05
# 4     Sofia    19       Cancún                   1   False     2026-05-05

# %%
cantidad = 1000000

# %%
import random

# %%
#Datos aleatorios
nombres = ["Ana", "Luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"]
ciudades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Mérida", "Tijuana", "Toluca"]
categorias = ["Tecnología", "Ropa", "Hogar", "Videojuegos", "Deportes", "Calzado", "Muebles", "IA"]

# %%
#Creacion del DataFrame
dfMillon = pd.DataFrame ({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "salario": [round(random.uniform(5000,50000),2) for _ in range(cantidad)],
    "activo" : [random.choice([True, False]) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "ciudad" : [random.choice(ciudades) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020,2026) for _ in range(cantidad)]
})

# %%
dfMillon.shape
# Out:
# (1000000, 7)

# %%
dfMillon.dtypes
# Out:
# nombre               str
# edad               int64
# salario          float64
# activo              bool
# categoria            str
# ciudad               str
# anio_registro      int64
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                 132
# nombre           62124634
# edad              8000000
# salario           8000000
# activo            1000000
# categoria        66736165
# ciudad           69875264
# anio_registro     8000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(213.37146282196045)
